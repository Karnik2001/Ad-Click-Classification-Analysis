# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree  import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import warnings
warnings.filterwarnings('ignore')

# %%
ad = pd.read_csv('/content/AdClick.csv')
ad.head()
# Out:
#    TimeSpentSeconds  PagesVisited AdType  Clicked
# 0         14.078043             4  Adult        0
# 1         90.303643             2  Adult        0
# 2         39.502371             7  Adult        1
# 3         27.388277             9  Adult        1
# 4          5.088746             6  Adult        0

# %%
for col in ad.columns:
  print(col,':',ad[col].nunique())
# Out:
# TimeSpentSeconds : 1288
# PagesVisited : 13
# AdType : 4
# Clicked : 2

# %%
for col in ad:
    if ad[col].dtype == 'O':
        codes, _ = pd.factorize(ad[col])
        ad[col] = codes + 1

# %% [markdown]
# ## Logistic Regression

# %%
X = ad.drop('Clicked', axis=1)
y = ad['Clicked']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_scaled = StandardScaler().fit_transform(X_train)
X_test_scaled = StandardScaler().fit_transform(X_test)

# %%
adlog = LogisticRegression(C = 0.01, tol = 1e-6, penalty = 'l2', max_iter= 50)
adlog.fit(X_scaled, y_train)
# Out:
# LogisticRegression(C=0.01, max_iter=50, tol=1e-06)

# %%
y_pred = adlog.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6816479400749064

# %%
adconfusion = confusion_matrix(y_test, y_pred)
adconfusion
# Out:
# array([[173,   9],
#        [ 76,   9]])

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.69      0.95      0.80       182
#      Clicked       0.50      0.11      0.17        85
#
#     accuracy                           0.68       267
#    macro avg       0.60      0.53      0.49       267
# weighted avg       0.63      0.68      0.60       267

# %% [markdown]
# ## Random Forest Classifier

# %%
adrandom = RandomForestClassifier(n_estimators=400, max_depth = 8, min_samples_leaf=3,
                                  min_samples_split=2)
adrandom.fit(X_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=3, n_estimators=400)

# %%
y_pred = adrandom.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6217228464419475

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.70      0.79      0.74       182
#      Clicked       0.37      0.27      0.31        85
#
#     accuracy                           0.62       267
#    macro avg       0.53      0.53      0.53       267
# weighted avg       0.59      0.62      0.60       267

# %% [markdown]
# ## Decision Tree Classifier

# %%
addecision = DecisionTreeClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=3)
addecision.fit(X_scaled, y_train)
# Out:
# DecisionTreeClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=3)

# %%
y_pred = addecision.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5805243445692884

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.68      0.73      0.70       182
#      Clicked       0.31      0.26      0.28        85
#
#     accuracy                           0.58       267
#    macro avg       0.49      0.49      0.49       267
# weighted avg       0.56      0.58      0.57       267

# %% [markdown]
# ## AdaBoost Classifier

# %%
adadboost = AdaBoostClassifier(n_estimators=300, learning_rate=0.18)
adadboost.fit(X_scaled, y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.18, n_estimators=300)

# %%
y_pred = adadboost.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6928838951310862

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.71      0.94      0.81       182
#      Clicked       0.56      0.16      0.25        85
#
#     accuracy                           0.69       267
#    macro avg       0.63      0.55      0.53       267
# weighted avg       0.66      0.69      0.63       267

# %% [markdown]
# ##Gradient Boost Classifier

# %%
adagradient = GradientBoostingClassifier(n_estimators=200, learning_rate=0.018)
adagradient.fit(X_scaled, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.018, n_estimators=200)

# %%
y_pred = adagradient.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6853932584269663

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.72      0.89      0.79       182
#      Clicked       0.51      0.25      0.33        85
#
#     accuracy                           0.69       267
#    macro avg       0.61      0.57      0.56       267
# weighted avg       0.65      0.69      0.65       267

# %% [markdown]
# ## Voting Classifier

# %%
adavote = VotingClassifier(estimators=[('log', adlog), ('rf', adrandom), ('dt', addecision)], voting ='hard')
adavote.fit(X_scaled, y_train)
# Out:
# VotingClassifier(estimators=[('log',
#                               LogisticRegression(C=0.01, max_iter=50,
#                                                  tol=1e-06)),
#                              ('rf',
#                               RandomForestClassifier(max_depth=8,
#                                                      min_samples_leaf=3,
#                                                      n_estimators=400)),
#                              ('dt',
#                               DecisionTreeClassifier(max_depth=9,
#                                                      min_samples_leaf=3,
#                                                      min_samples_split=3))])

# %%
y_pred = adavote.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6404494382022472

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.69      0.86      0.76       182
#      Clicked       0.37      0.18      0.24        85
#
#     accuracy                           0.64       267
#    macro avg       0.53      0.52      0.50       267
# weighted avg       0.59      0.64      0.60       267

# %% [markdown]
# ## Support Vector Classifier

# %%
adasvc = SVC(kernel='sigmoid', C=0.01)
adasvc.fit(X_scaled, y_train)
# Out:
# SVC(C=0.01, kernel='sigmoid')

# %%
y_pred = adasvc.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6816479400749064

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.68      1.00      0.81       182
#      Clicked       0.00      0.00      0.00        85
#
#     accuracy                           0.68       267
#    macro avg       0.34      0.50      0.41       267
# weighted avg       0.46      0.68      0.55       267

# %% [markdown]
# ## K-Nearest Neighbor

# %%
adaknn = KNeighborsClassifier(n_neighbors=12, weights='uniform')
adaknn.fit(X_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_pred = adaknn.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6629213483146067

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.71      0.86      0.78       182
#      Clicked       0.44      0.24      0.31        85
#
#     accuracy                           0.66       267
#    macro avg       0.58      0.55      0.54       267
# weighted avg       0.62      0.66      0.63       267

# %% [markdown]
# ##Gaussian Naive Bayes

# %%
adagaussian = GaussianNB(var_smoothing=1e-02)
adagaussian.fit(X_scaled, y_train)
# Out:
# GaussianNB(var_smoothing=0.01)

# %%
y_pred = adagaussian.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.6816479400749064

# %%
labels = ['Not Clicked', 'Clicked']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Not Clicked       0.71      0.90      0.79       182
#      Clicked       0.50      0.21      0.30        85
#
#     accuracy                           0.68       267
#    macro avg       0.60      0.56      0.55       267
# weighted avg       0.64      0.68      0.64       267

# %% [markdown]
# ## Citations
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html
#
# ChatGPT
